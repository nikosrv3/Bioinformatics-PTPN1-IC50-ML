# %% [markdown]
# <a href="https://colab.research.google.com/github/nikosrv3/Bioinformatics-PTPN1-IC50-ML/blob/main/Bioactivity_Data_PTPN1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery PTPN1**
#
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! mkdir "/content/drive/My Drive/Colab Notebooks/data"

# %% [markdown]
# ## **Installing libraries**

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target**
#
# > Add blockquote

# %% [markdown]
# ### **Target search for PTPN1**

# %%
# Target search for ptpn1
target = new_client.target
target_query = target.search('ptpn1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P20417', 'xref_name': None, 'xre...  Rattus norvegicus
# 1  [{'xref_id': 'P18031', 'xref_name': None, 'xre...       Homo sapiens
# 2  [{'xref_id': 'P35821', 'xref_name': None, 'xre...       Mus musculus
#
#                          pref_name  score  species_group_flag  \
# 0  Protein-tyrosine phosphatase 1B   15.0               False
# 1  Protein-tyrosine phosphatase 1B   15.0               False
# 2  Protein-tyrosine phosphatase 1B   13.0               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL2371  [{'accession': 'P20417', 'component_descriptio...
# 1        CHEMBL335  [{'accession': 'P18031', 'component_descriptio...
# 2       CHEMBL3336  [{'accession': 'P35821', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN   10116
# 1  SINGLE PROTEIN    9606
# 2  SINGLE PROTEIN   10090

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL335'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None       Not Active
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4563  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4564  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4565  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4566  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4567  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('ptpn1_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-21-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# 5                                                  None             None
# ...                                                 ...              ...
# 4563  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4564  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4565  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4566  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 3710

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# 5                                                  None             None
# ...                                                 ...              ...
# 4562  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4563  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4564  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4565  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4567  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 1          CHEMBL301254           COC(=O)c1ccc(C2=CC(=O)C(=O)c3ccccc32)cc1
# 2           CHEMBL58435                       CC(C)C1=CC(=O)C(=O)c2ccccc21
# 3           CHEMBL57157      CCN(CC)C(=O)CCC1=C(c2ccccc2)c2ccccc2C(=O)C1=O
# 4          CHEMBL292444  CCOC(=O)c1ccc(CCC2=C(c3ccccc3)c3ccccc3C(=O)C2=...
# 5           CHEMBL60707              O=C1C=C(c2c[nH]c3ccccc23)c2ccccc2C1=O
# ...                 ...                                                ...
# 4562      CHEMBL5267587  C[C@@]12CC[C@@H]3[C@@](CC[C@H]4[C@@]3(C)CCC[C@...
# 4563      CHEMBL5282928  C[C@@]12CC[C@@H]3[C@@](CC[C@H]4[C@@]3(C)CCC[C@...
# 4564       CHEMBL518780  CCOC(=O)[C@]1(C)CCC[C@@]2(C)[C@@H]3CC[C@@]4(C)...
# 4565      CHEMBL5289855  CCOC(=O)[C@]1(C)CCC[C@@]2(C)[C@@H]3CC[C@@]4(C)...
# 4567       CHEMBL462653  C[C@@]12CC[C@@H]3[C@@](CC[C@H]4[C@@]3(C)CCC[C@...
#
#      standard_value
# 1            1540.0
# 2           10130.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('ptpn1_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('ptpn1_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL301254           COC(=O)c1ccc(C2=CC(=O)C(=O)c3ccccc32)cc1
# 1           CHEMBL58435                       CC(C)C1=CC(=O)C(=O)c2ccccc21
# 2           CHEMBL57157      CCN(CC)C(=O)CCC1=C(c2ccccc2)c2ccccc2C(=O)C1=O
# 3          CHEMBL292444  CCOC(=O)c1ccc(CCC2=C(c3ccccc3)c3ccccc3C(=O)C2=...
# 4           CHEMBL60707              O=C1C=C(c2c[nH]c3ccccc23)c2ccccc2C1=O
# ...                 ...                                                ...
# 3705      CHEMBL5267587  C[C@@]12CC[C@@H]3[C@@](CC[C@H]4[C@@]3(C)CCC[C@...
# 3706      CHEMBL5282928  C[C@@]12CC[C@@H]3[C@@](CC[C@H]4[C@@]3(C)CCC[C@...
# 3707       CHEMBL518780  CCOC(=O)[C@]1(C)CCC[C@@]2(C)[C@@H]3CC[C@@]4(C)...
# 3708      CHEMBL5289855  CCOC(=O)[C@]1(C)CCC[C@@]2(C)[C@@H]3CC[C@@]4(C)...
# 3709       CHEMBL462653  C[C@@]12CC[C@@H]3[C@@](CC[C@H]4[C@@]3(C)CCC[C@...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('ptpn1_bioactivity_data_curated.csv', index=False)

# %%
! zip ptpn1.zip *.csv
# Out:
#   adding: a2ar_bioactivity_data_raw.csv (deflated 91%)
#   adding: ptpn1_bioactivity_data_curated.csv (deflated 83%)
#   adding: ptpn1_bioactivity_data_preprocessed.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 3464
# -rw-r--r-- 1 root root 2494564 Oct  9 20:00 a2ar_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  362853 Oct  9 20:01 ptpn1_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  326389 Oct  9 20:01 ptpn1_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  351902 Oct  9 20:01 ptpn1.zip
# drwxr-xr-x 1 root root    4096 Oct  7 18:37 sample_data

# %%
! cp ptpn1_bioactivity_data_curated.csv "/content/drive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/drive/My Drive/Colab Notebooks/data"
# Out:
# ptpn1_bioactivity_data_curated.csv

# %% [markdown]
# ---
